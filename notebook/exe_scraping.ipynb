# %%
data\html\race

# %%
from tqdm.notebook import tqdm
from makeRawData import makeRaceData

# %%
startYM = "201501"
endYM = "201501"
a=makeRaceData(startYM,endYM)
a.makeYMList()
a.makeRaceDateURLList()
a.makeRaceURLList()
a.screpingRaceHTML(skip=True)
a.makeRawDataRace(skip=True)
# Out:
# 201501～201501のレース情報のデータを作成します。
# ...
# makeRawDataRace:   0%|          | 0/288 [00:00<?, ?it/s, raceID=201506010101]d:\work\keibaAnalysis\development\notebook\makeRawData.py:261: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 261 of the file d:\work\keibaAnalysis\development\notebook\makeRawData.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(html) #htmlをsoupオブジェクトへ
# ...
